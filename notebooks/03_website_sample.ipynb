# %% [markdown]
# # Bonus : construct dataset for the website

# %% [markdown]
# ## 1. Library import

# %%
import pandas as pd 

from pathlib import Path
import sys 

# Root of the project 
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))


from src.utils.config import (
    FIGURES_DIR,
    METRICS_DIR,
    MODELS_DIR
)

from src.data_loading.data_sample_pred import predict_on_sample
from src.utils.io import load_model
from src.utils.boards import download_boards

# %% [markdown]
# ## 2. Data import

# %% [markdown]
# We first import the dataset we will use to show our results in the website. It contains the moves played by Magnus and his opponents in 5 different games. These games are not included in the training dataset.

# %%
# Import the dataframe we will use. 
df_samp = pd.read_csv(METRICS_DIR / "data_sample_magnus.csv")
df_samp
# Out:
#      ID_game  ID_move        PlayerName  PlayerSide  PlayerElo  PlayerTitle  \
# 0       2291        1   Carlsen, Magnus           1     3298.0            4
# 1       2291        2    Dowgird, Filip           0     2683.0            2
# 2       2291        3   Carlsen, Magnus           1     3298.0            4
# 3       2291        4    Dowgird, Filip           0     2683.0            2
# 4       2291        5   Carlsen, Magnus           1     3298.0            4
# ..       ...      ...               ...         ...        ...          ...
# 347     4688       68   Carlsen, Magnus           0     3221.0            0
# 348     4688       69  Nakamura, Hikaru           1     3258.0            0
# 349     4688       70   Carlsen, Magnus           0     3221.0            0
# 350     4688       71  Nakamura, Hikaru           1     3258.0            0
# 351     4688       72   Carlsen, Magnus           0     3221.0            0
#
#      MagnusElo  OpponentElo  OpponentTitle      OpponentName  ...  \
# 0         3298       2683.0              2    Dowgird, Filip  ...
# 1         3298       2683.0              2    Dowgird, Filip  ...
# 2         3298       2683.0              2    Dowgird, Filip  ...
# 3         3298       2683.0              2    Dowgird, Filip  ...
# 4         3298       2683.0              2    Dowgird, Filip  ...
# ..         ...          ...            ...               ...  ...
# 347       3221       3258.0              0  Nakamura, Hikaru  ...
# 348       3221       3258.0              0  Nakamura, Hikaru  ...
# 349       3221       3258.0              0  Nakamura, Hikaru  ...
# 350       3221       3258.0              0  Nakamura, Hikaru  ...
# 351       3221       3258.0              0  Nakamura, Hikaru  ...
#
#                                              FEN_after  OpponentTimeSpent  \
# 0    rnbqkbnr/pppppppp/8/8/8/1P6/P1PPPPPP/RNBQKBNR ...                0.0
# 1    rnbqkbnr/ppp1pppp/8/3p4/8/1P6/P1PPPPPP/RNBQKBN...                1.0
# 2    rnbqkbnr/ppp1pppp/8/3p4/8/1P6/PBPPPPPP/RN1QKBN...                3.0
# 3    rnbqkb1r/ppp1pppp/5n2/3p4/8/1P6/PBPPPPPP/RN1QK...                2.0
# 4    rnbqkb1r/ppp1pppp/5n2/3p4/8/1P3N2/PBPPPPPP/RN1...                1.0
# ..                                                 ...                ...
# 347    3r4/1p4kp/p5p1/4Np2/2P1p3/1PN5/4K3/8 w - - 2 35                1.0
# 348    3r4/1p4kp/p5p1/3NNp2/2P1p3/1P6/4K3/8 b - - 3 35               14.0
# 349     3r4/1p4kp/p7/3NNpp1/2P1p3/1P6/4K3/8 w - - 0 36                0.0
# 350     3r4/1p4kp/p7/3NNpp1/2P1p3/1P2K3/8/8 b - - 1 36                5.0
# 351     3r4/1p4k1/p7/3NNppp/2P1p3/1P2K3/8/8 w - - 0 37                4.0
#
#      TimeSpent time_spent_before  TimeRatio  TimePressure  MoveTimeFraction  \
# 0          1.0               0.0   0.994475             0          0.005525
# 1          3.0               0.0   0.994475             0          0.016575
# 2          2.0               1.0   1.005587             0          0.011050
# 3          1.0               3.0   0.988889             0          0.005587
# 4          2.0               2.0   1.000000             0          0.011111
# ..         ...               ...        ...           ...               ...
# 347       14.0               1.0   9.400000             0          0.291667
# 348        0.0               1.0   0.114286             1          0.000000
# 349        5.0              14.0   5.666667             0          0.142857
# 350        4.0               0.0   0.161290             1          0.666667
# 351        1.0               5.0  10.000000             0          0.032258
#
#      IsCastling  IsPromotion  IsEnPassant
# 0             0            0            0
# 1             0            0            0
# 2             0            0            0
# 3             0            0            0
# 4             0            0            0
# ..          ...          ...          ...
# 347           0            0            0
# 348           0            0            0
# 349           0            0            0
# 350           0            0            0
# 351           0            0            0
#
# [352 rows x 34 columns]

# %%
# Load the model to test if it works
model_timespent = load_model(MODELS_DIR, "random_forest_time_spent.pkl")
# Out:
# Model loaded successfully

# %% [markdown]
# ## 3. Create exemple dataset

# %% [markdown]
# ### 3.0 Functions

# %%
TRAIN_FEATURES = ['ID_move', 
                 'PlayerSide', 
                 'PlayerTimeLeft', 
                 'OpponentTimeLeft', 
                 'Phase', 'Increment', 
                 'IsCapture', 
                 'IsCheck', 
                 'OppIsCaptured', 
                 'OppIsCheck', 
                 'NumLegalMoves', 
                 'OpponentTimeSpent', 
                 "TimeTotal", 
                 "Phase",
                "TimeRatio",
                "TimePressure",


                    "IsCastling",
                    "IsPromotion",
                    "IsEnPassant"] 

FINAL_FEATURES = ["ID_game", "ID_move", "PlayerName", "PlayerSide","FEN", "TimeSpent", "TimeSpentPred"]

# %% [markdown]
# We create a function to build the dataset we will use to show our results. This function associate to every move Magnus play in my sample dataframe the Time spend predict by my model. It associate a value 'NaN' to the moves played by the opponents.

# %% [markdown]
# ### 3.1 Predict the time spend in our data sample

# %%
# Use the function to associate every move to a prediction 
df_samp_pred = predict_on_sample(df_samp, model_timespent, TRAIN_FEATURES, FINAL_FEATURES)

# Print the result 
df_samp_pred.head(25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Use the function to associate every move to a prediction
# ----> 2 df_samp_pred = predict_on_sample(df_samp, model_timespent, TRAIN_FEATURES, FINAL_FEATURES)
#       4 # Print the result
#       5 df_samp_pred.head(25)
#
# File c:\Users\elija\OneDrive\Bureau\magnus-time-prediction-ml\src\data_loading\data_sample_pred.py:22, in predict_on_sample(df_samp, model, train_features, final_features)
#      19 X_pred = df_out.loc[mask_magnus, train_features]
#      21 # Prédiction
# ---> 22 df_out.loc[mask_magnus, "TimeSpentPred"] = model.predict(X_pred)
#      24 return df_out[final_features]
#
# File c:\Users\elija\OneDrive\Bureau\Projet de recherche encadré\Projet sciences des données\venv_tf\Lib\site-packages\sklearn\ensemble\_forest.py:1065, in ForestRegressor.predict(self, X)
#    1063 check_is_fitted(self)
#    1064 # Check data
# -> 1065 X = self._validate_X_predict(X)
#    1067 # Assign chunk of trees to jobs
#    1068 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\elija\OneDrive\Bureau\Projet de recherche encadré\Projet sciences des données\venv_tf\Lib\site-packages\sklearn\ensemble\_forest.py:637, in BaseForest._validate_X_predict(self, X)
#     634 else:
#     635     ensure_all_finite = True
# --> 637 X = validate_data(
#     638     self,
#     639     X,
#     640     dtype=DTYPE,
#     641     accept_sparse="csr",
#     642     reset=False,
#     643     ensure_all_finite=ensure_all_finite,
#     644 )
#     645 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     646     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\elija\OneDrive\Bureau\Projet de recherche encadré\Projet sciences des données\venv_tf\Lib\site-packages\sklearn\utils\validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File c:\Users\elija\OneDrive\Bureau\Projet de recherche encadré\Projet sciences des données\venv_tf\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - OpponentTimeSpent
# Feature names seen at fit time, yet now missing:
# - OpponentTimeSpend

# %% [markdown]
# ### 3.2 Create boards images

# %%
# Use the function to create all the boards by using the FEN and download it in the results. We will use it for the website. 
download_boards(df_samp_pred, FIGURES_DIR / "boards")
# Out:
# Old board images successfully deleted
# New board images successfully generated
